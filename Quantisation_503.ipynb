# %%
import os

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms.v2 as transforms

from binaryconnect import BC
from models import DenseNet121
from utils import get_device, get_model_size_mb, get_test_cifar10_dataloader, test

# %%
from torch import dtype as T_dtype
from torch.quantization import get_default_qconfig
from torch.ao.quantization.quantize_fx import prepare_fx, convert_fx
from torch.utils.data.dataloader import DataLoader

QCONFIG = get_default_qconfig('fbgemm')
QCONFIG_DEFAULT = {
    "": QCONFIG,
    "object_type": [
        (torch.nn.Conv2d, QCONFIG),
        (torch.nn.Linear, QCONFIG),
        (torch.nn.ReLU, QCONFIG),
        (torch.nn.BatchNorm2d, QCONFIG),
    ]
}

def quantise_dynamic(
        model: nn.Module,
        spec: tuple = {torch.nn.Linear},
        dtype: T_dtype = torch.qint8,
    ) -> nn.Module:
    return torch.quantization.quantize_dynamic(
        model, spec, dtype=dtype,
    )

def quantise_static(
        model: nn.Module,
        calibration_loader: DataLoader,
        qconfig_dict: dict = QCONFIG_DEFAULT,
    ) -> nn.Module:
    model = model.to('cpu')
    example_inputs = (next(iter(calibration_loader))[0],)
    prepared_model = prepare_fx(model, qconfig_dict, example_inputs)
    return convert_fx(prepared_model)

# %%
import pickle
device = get_device()

with open("train_results.pkl", "rb") as f:
    res = pickle.load(f)
state_dict, acc, train_accs, val_accs = res.values()

model = DenseNet121()
model.load_state_dict(state_dict)

model = model.to(device)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 import pickle
# ----> 2 device = get_device()
#       4 with open("train_results.pkl", "rb") as f:
#       5     res = pickle.load(f)
#
# NameError: name 'get_device' is not defined

# %%
from utils import load_trained_model

model, _ = load_trained_model()

# %%
test_loader = get_test_cifar10_dataloader()

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

x = [28.353676, 28.313666, 7.89627, 14.27406, 0.715]
y = [90.44, 90.38, 10.0, 90.42, 81.49]

labels = ['Dynamic Quant', 'Original','Static Quant', 'Half', 'Binary Connect']
colors = ['red', 'blue', 'green', 'orange', 'purple']

for xi, yi, label, color in zip(x, y, labels, colors):
    plt.scatter(xi, yi, label=label, color=color)

plt.xlabel("Size (MB)")
plt.ylabel("Accuracy (%)")
plt.title("Model Size (MB) v. Accuracy for Various Quantisation Methods")
plt.legend()

# %%
from numpy import linspace
x = linspace(0.1, 1, 10)[:-1]

# %%
no_quant_glob_prun = [(1.8121627983238828, 88.61),
 (1.643848178818579, 88.77),
 (1.4950563437762647, 88.29),
 (1.3657868602068894, 86.92),
 (1.2560399588083273, 79.38),
 (1.1658156395805779, 35.25),
 (1.0951139025236416, 15.49),
 (1.0439348079012516, 11.94),
 (1.012278206780244, 10.0)]
half_quant_glob_prun = [(0.9060813991619414, 88.59),
 (0.8219240894092895, 85.69),
 (0.7475281718881324, 80.73),
 (0.6828934301034447, 73.47),
 (0.6280199794041637, 53.39),
 (0.5829078197902889, 26.53),
 (0.5475569512618208, 17.65),
 (0.5219674039506258, 10.0),
 (0.506139103390122, 10.0)]

# %%
plt.scatter(accs1, y1, label="No quantisation")
plt.scatter(accs2, y2, label="Half quantisation")

for i, (xi, yi) in enumerate(zip(accs1, y1)):
    plt.text(xi, yi, f"{x[i]:.2f}", fontsize=8, ha='left', va='top')
for i, (xi, yi) in enumerate(zip(accs2, y2)):
    plt.text(xi, yi, f"{x[i]:.2f}", fontsize=8, ha='left', va='top')

plt.legend()
plt.xlabel("Accuracy (%)")
plt.ylabel("Score")
plt.title("Global Pruning Accuracy v Score")
# Out:
# Text(0.5, 1.0, 'Global Pruning Accuracy v Score')

# %%
y1 = [r[0] for r in no_quant_glob_prun]
accs1 = [r[1] for r in no_quant_glob_prun]
y2 = [r[0] for r in half_quant_glob_prun]
accs2 = [r[1] for r in half_quant_glob_prun]

plt.scatter(x, y1, label="No quantisation")
plt.scatter(x, y2, label="Half quantisation")

# Label each point in y1
for i, (xi, yi) in enumerate(zip(x, y1)):
    plt.text(xi, yi, f"{accs1[i]}", fontsize=8, ha='left', va='bottom')

# Label each point in y2
for i, (xi, yi) in enumerate((x, y2)):
    plt.text(xi, yi, f"{accs2[i]}", fontsize=8, ha='left', va='top')

plt.xlabel("Prune Ratio")
plt.ylabel("Score")
plt.legend()
plt.title("Global Pruning Scores for Various Prune Ratios")
# Out:
# Text(0.5, 1.0, 'Global Pruning Scores for Various Prune Ratios')

# %%
plt.scatter(accs1, y1, label="No Quantisation")
plt.scatter(accs2, y2, label="Half Quantisation")
plt.title("Global Pruning Score v Accuracy ")
plt.xlabel("Accurancy (%)")
plt.ylabel("Score")
plt.legend()

# %%
from utils import calculate_score, count_nonzero_parameters, get_macs

# %%
import pickle

with open("gradual_prune_half_quant_res.pkl", "rb") as f:
    res = pickle.load(f)

# %%
model.half()
# Out:
# DenseNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (dense1): Sequential(
#     (0): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (1): Bottleneck(
#       (bn1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (2): Bottleneck(
# ...

# %%
params_ref, ops_ref = count_nonzero_parameters(model), get_macs(model, half=True)

# %%
res2 = {}
for ratio, list_ in res.items():
    list_2 = []
    accs = []
    for i, tup in enumerate(list_):
        score = calculate_score(
            1 - (1 * (1 - ratio) ** (i + 1)), 0, 16, 16, 6956297 * ((1 - ratio) ** (i + 1)), ops_ref, params_ref, ops_ref,
        )
        list_2.append(score)
        accs.append(tup[1])
    res2[ratio] = {"scores": list_2, "accs": accs}

# %%
res2
# Out:
# {0.2: {'scores': [0.7200000000000001, 0.5248000000000002, 0.3870720000000001],
#   'accs': [65.05, 39.35, 18.22]},
#  0.3: {'scores': [0.595, 0.36504999999999993, 0.23032449999999996],
#   'accs': [48.23, 15.29, 10.42]},
#  0.4: {'scores': [0.48, 0.2448, 0.13132799999999997],
#   'accs': [30.21, 10.45, 9.94]}}

# %%
r1_x = res2[0.2]["accs"]
r1_y = res2[0.2]["scores"]

r2_x = res2[0.3]["accs"]
r2_y = res2[0.3]["scores"]

r3_x = res2[0.4]["accs"]
r3_y = res2[0.4]["scores"]

plt.scatter(r1_x, r1_y, label="Pruning Ratio 0.2")
plt.scatter(r2_x, r2_y, label="Pruning Ratio 0.3")
plt.scatter(r3_x, r3_y, label="Pruning Ratio 0.4")
plt.title("Gradual Pruning (3 round, 30 epochs) Half Quant. Score v Accuracy ")
plt.xlabel("Accurancy (%)")
plt.ylabel("Score")
plt.legend()

# %%
6956297 * ((1 - ratio) ** (i + 1))
# Out:
# 1502560.1519999998

# %%
0.2 * 0.2
# Out:
# 0.04000000000000001

# %%
1 - (1 * (1 - 0.2) ** 2)
# Out:
# 0.3599999999999999

# %%
from utils import pickle_dump

res = {"bc_test_acc": 81.49}
pickle_dump(res, "bc_test_acc")

# %%
og_acc, _ = test(
    test_loader,
    model,
)

# %%
og_acc
# Out:
# 90.44

# %%
og_size = get_model_size_mb(model)
og_size
# Out:
# 28.353676

# %%
model.to("cpu")
dynamic_quantised_model = torch.quantization.quantize_dynamic(
        model, {torch.nn.Linear}, dtype=torch.qint8,
    )
dynamic_quantised_size = get_model_size_mb(dynamic_quantised_model)
dynamic_quantised_size
# Out:
# 28.313666

# %%
dynamic_quantised_acc, _ = test(
    test_loader,
    dynamic_quantised_model,
    device="cpu"
)

# %%
dynamic_quantised_acc
# Out:
# 90.38

# %%
model.eval() 
static_quantised_model = quantise_static(model, test_loader)
static_quantised_size = get_model_size_mb(static_quantised_model)
static_quantised_size
# Out:
# /users/local/b24richa/EDL/.venv/lib/python3.12/site-packages/torch/ao/quantization/quantize_fx.py:146: FutureWarning: Passing a QConfig dictionary to prepare is deprecated and will not be supported in a future version. Please pass in a QConfigMapping instead.
#   prepared = prepare(
# /users/local/b24richa/EDL/.venv/lib/python3.12/site-packages/torch/ao/quantization/observer.py:229: UserWarning: Please use quant_min and quant_max to specify the range for observers.                     reduce_range will be deprecated in a future release of PyTorch.
#   warnings.warn(
# /users/local/b24richa/EDL/.venv/lib/python3.12/site-packages/torch/ao/quantization/observer.py:1318: UserWarning: must run observer before calling calculate_qparams.                                    Returning default scale and zero point
#   warnings.warn(
# 7.89627

# %%
static_quantised_model = static_quantised_model.to("cpu")

# %%
static_quantised_acc, _ = test(
    test_loader,
    static_quantised_model,
    device="cpu"
)

# %%
static_quantised_acc
# Out:
# 10.0

# %%
model = model.to(device)
half_model = model.half()
half_model_size = get_model_size_mb(half_model)
half_model_size
# Out:
# 14.27406

# %%
half_model_acc, _ = test(
    test_loader,
    half_model,
    half=True
)

# %%
half_model_acc
# Out:
# 90.42

# %%
from utils import get_best_transformations, get_cifar10_train_val_loaders, load_untrained_model, run_epochs, get_dataloader, get_train_cifar10_dataset

train_transforms = get_best_transformations()
training_details = load_untrained_model("DenseNet121")
# train_loader, val_loader = get_cifar10_train_val_loaders()
train_loader = get_dataloader(get_train_cifar10_dataset(subset=True, num_subset=1000))
val_loader = get_dataloader(get_train_cifar10_dataset(subset=True, num_subset=200))

# %%
model.train()
# model.to("cpu")
model.qconfig = torch.quantization.get_default_qat_qconfig('fbgemm')
torch.quantization.prepare_qat(model, inplace=True)

best_acc, train_accs, test_accs = run_epochs(
    training_details["model"],
    train_loader,
    val_loader,
    training_details,
    n_epochs=1,
)
# Out:
# Epoch: 0
# Saving..

# %%
model.to("cpu")
qat_model = torch.quantization.convert(model, inplace=True)

# %%
get_model_size_mb(qat_model)
# Out:
# 8.07959

# %%
# qat_model.to("cpu")
qat_acc, _ = test(
    test_loader,
    qat_model,
    device="cpu"
)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[63], line 2
#       1 # qat_model.to("cpu")
# ----> 2 qat_acc, _ = test(
#       3     test_loader,
#       4     qat_model,
#       5     device="cpu"
#       6 )
#
# File /users/local/b24richa/EDL/utils.py:197, in test(test_loader, net, criterion, device, half)
#     194 if half:
#     195     inputs = inputs.half()
# --> 197 outputs = net(inputs)
#     198 loss = criterion(outputs, targets)
#     200 test_loss += loss.item()
#
# File /users/local/b24richa/EDL/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# ...

# %%
qat_model
# Out:
# DenseNet(
#   (conv1): QuantizedConv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), scale=1.0, zero_point=0, padding=(1, 1), bias=False)
#   (dense1): Sequential(
#     (0): Bottleneck(
#       (bn1): QuantizedBatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): QuantizedConv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), scale=1.0, zero_point=0, bias=False)
#       (bn2): QuantizedBatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): QuantizedConv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), scale=1.0, zero_point=0, padding=(1, 1), bias=False)
#     )
#     (1): Bottleneck(
#       (bn1): QuantizedBatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): QuantizedConv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), scale=1.0, zero_point=0, bias=False)
#       (bn2): QuantizedBatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
import torch
from torch.quantization import get_default_qconfig
from torch.ao.quantization.quantize_fx import prepare_fx, convert_fx

model = model.to('cpu')
model.eval()



example_inputs = (next(iter(train_loader))[0],)
prepared_model = prepare_fx(model, qconfig_dict, example_inputs)
quantized_model = convert_fx(prepared_model)

print(quantized_model)
# Out:
# /users/local/b24richa/EDL/.venv/lib/python3.12/site-packages/torch/ao/quantization/quantize_fx.py:146: FutureWarning: Passing a QConfig dictionary to prepare is deprecated and will not be supported in a future version. Please pass in a QConfigMapping instead.
#   prepared = prepare(
# /users/local/b24richa/EDL/.venv/lib/python3.12/site-packages/torch/ao/quantization/observer.py:229: UserWarning: Please use quant_min and quant_max to specify the range for observers.                     reduce_range will be deprecated in a future release of PyTorch.
#   warnings.warn(
# /users/local/b24richa/EDL/.venv/lib/python3.12/site-packages/torch/ao/quantization/observer.py:1318: UserWarning: must run observer before calling calculate_qparams.                                    Returning default scale and zero point
#   warnings.warn(
# GraphModule(
#   (conv1): QuantizedConv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), scale=1.0, zero_point=0, padding=(1, 1), bias=False)
#   (dense1): Module(
# ...

# %%
print_size_of_model(quantized_model)
# Out:
# Size (MB): 7.89627

# %%
model = model.to("cpu")
for m in model.modules():
    if isinstance(m, (torch.nn.Conv2d, torch.nn.Linear)):
        m.qconfig = torch.quantization.get_default_qconfig('fbgemm')
        torch.quantization.prepare(m, inplace=True)
        torch.quantization.convert(m, inplace=True)
    else:
        continue
# Out:
# /users/local/b24richa/EDL/.venv/lib/python3.12/site-packages/torch/ao/quantization/observer.py:229: UserWarning: Please use quant_min and quant_max to specify the range for observers.                     reduce_range will be deprecated in a future release of PyTorch.
#   warnings.warn(

# %%
print(model)
# Out:
# DenseNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (dense1): Sequential(
#     (0): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (1): Bottleneck(
#       (bn1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (2): Bottleneck(
# ...

# %%
model = model.to("cuda")

# %%
print_size_of_model(model)
# Out:
# Size (MB): 28.353676

# %%
import os

import torch
import torch.nn as nn
import torch.optim as optim

from binaryconnect import BC
from models import DenseNet121
from utils import load_trained_model, load_untrained_model, get_device, get_model_size_mb, get_test_cifar10_dataloader, test
from utils import get_best_transformations
# Out:
# Compose(
#       RandomAffine(degrees=[0.0, 0.0], shear=[10.0, 20.0, 0.0, 10.0], interpolation=InterpolationMode.NEAREST, fill=0)
#       RandomHorizontalFlip(p=0.5)
#       ToImage()
#       ToDtype(scale=True)
#       Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.2023, 0.1994, 0.201], inplace=False)
# )

# %%
with open("transforms/transforms_best_trial.pkl", "rb") as f:
    res = pickle.load(f)

# %%
res
# Out:
# {'params': {'userotation': False,
#   'usetranslation': False,
#   'useshearing': True,
#   'usehorizontal_flip': True,
#   'usevertical_flip': False,
#   'usecrop': False,
#   'usecolor_jitter': False,
#   'usenoise_injection': False,
#   'usekernel': False,
#   'userandom_erasing': False,
#   'usecutout': False,
#   'usehide_and_seek': False},
#  'value': 87.58}

# %%
transforms_ =get_best_transformations()

# %%
test_loader = get_test_cifar10_dataloader()

model, _ = load_trained_model()
mymodelbc = BC(model)
train_details = load_untrained_model("DenseNet121")

# %%
bc_model_acc, _ = test(
    test_loader,
    mymodelbc,
    # half=True
)

# %%
net.eval()
test_loss = 0
correct = 0
total = 0
with torch.no_grad():
    for inputs, targets in test_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        if half:
            inputs = inputs.half()

        outputs = net(inputs)
        loss = criterion(outputs, targets)

        test_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

# %%
bc_model_acc
# Out:
# 10.0

# %%
get_model_size_mb(mymodelbc)
# Out:
# 28.354067

# %%
mymodelbc.binarisation()

# %%
get_model_size_mb(mymodelbc)
# Out:
# 28.354067

# %%
import pickle

with open("transforms/autoaugment_acc.pkl", "rb") as f:
    res = pickle.load(f)

# %%
res
# Out:
# {'autoaugment_acc': 85.69}

# %%
best_acc = 0
start_epoch = 0
n_epochs = 10

for epoch in range(start_epoch, start_epoch+n_epochs):
    mymodelbc.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)

        optimiser.zero_grad()
        outputs = mymodelbc(inputs)
        loss = criterion(outputs, targets)

        loss.backward()
        optimiser.step()
        mymodelbc.clip()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 21
#      18 optimiser.step()
#      19 mymodelbc.clip()
# ---> 21 train_loss += loss.item()
#      22 _, predicted = outputs.max(1)
#      23 total += targets.size(0)
#
# KeyboardInterrupt:

# %%
from utils import train


def quantise_aware_train(
        train_loader: DataLoader,
        model: nn.Module,
        optimiser: "Optimizer",
        criterion,
        qconfig: str = "fbgemm",
        device: str = "cuda",
        n_epochs: int = 500,
    ) -> None:
    model.qconfig = torch.quantization.get_default_qat_qconfig(qconfig)
    torch.quantization.prepare_qat(model, inplace=True)
    
    for _ in range(n_epochs):
        acc, loss = train(
            train_loader,
            model,
            optimiser,
            criterion,
            device,
        )

    model = model.to('cpu')
    torch.quantization.convert(model, inplace=True)
    model = model.to(device)

# %%
from torchvision.transforms import v2 as transformsv2

# %%
from utils import get_cifar10_train_val_loaders, ROOT_DIR, DEFAULT_TRANSFORM, print_size_of_model, subset_data

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.quantization
from torchvision.datasets import CIFAR10
from torch.utils.data.dataloader import DataLoader

train_loader, val_loader = get_cifar10_train_val_loaders(subset=True, num_subset=5000)


# Download CIFAR-10 dataset (train and test)
train_dataset = subset_data(CIFAR10(root=ROOT_DIR, train=True, download=True, transform=DEFAULT_TRANSFORM), 5000)
test_dataset = CIFAR10(root=ROOT_DIR, train=False, download=True, transform=DEFAULT_TRANSFORM)

# Create DataLoaders
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2)


# Define a simple model (e.g., for QAT)
class SimpleModel(nn.Module):
    def __init__(self):
        super(SimpleModel, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, 3)
        self.fc1 = nn.Linear(16 * 30 * 30, 10)
    
    def forward(self, x):
        x = self.conv1(x)
        x = x.flatten(1)
        x = self.fc1(x)
        return x

# Initialize model, move to CUDA
model = SimpleModel().to('cuda')

print_size_of_model(model)



# Now, the model is quantized and can be used for inference.
print_size_of_model(model)
# Out:
# Size (MB): 0.579704
# 0
# /users/local/b24richa/EDL/.venv/lib/python3.12/site-packages/torch/ao/quantization/observer.py:229: UserWarning: Please use quant_min and quant_max to specify the range for observers.                     reduce_range will be deprecated in a future release of PyTorch.
#   warnings.warn(
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 61
#      58         optimizer.step()
#      60 # Convert to quantized model after training
# ---> 61 torch.quantization.convert(model, inplace=True)
#      63 # Now, the model is quantized and can be used for inference.
#      64 print_size_of_model(model)
#
# ...

# %%
model = model.to('cpu')  # Move the model back to CPU for conversion
torch.quantization.convert(model, inplace=True)
# Out:
# SimpleModel(
#   (conv1): QuantizedConv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), scale=0.06295403838157654, zero_point=63)
#   (fc1): QuantizedLinear(in_features=14400, out_features=10, scale=0.1440950483083725, zero_point=59, qscheme=torch.per_channel_affine)
# )

# %%
print_size_of_model(model)
# Out:
# Size (MB): 0.148866

# %%
model = model.to('cuda')

# %%
print_size_of_model(model)
# Out:
# Size (MB): 0.148866
